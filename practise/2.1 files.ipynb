# %%
# opening files
fhand = open('mbox.txt')
print(fhand)
# Out:
# <_io.TextIOWrapper name='mbox.txt' mode='r' encoding='cp1252'>

# %%
#newline character #\n
stuff ='Humphrey\nNduati\nGithu'
stuff
'Humphrey\nNduati\nGithu'
print(stuff)

len(stuff)
# Out:
# Humphrey
# Nduati
# Githu
# 21

# %%
#reading a file#count #for loop
fhand = open ('mbox.txt')
count = 0
for line in fhand:
    count = count + 1
print('Line count:', count)     #number of lines in the file
# Out:
# Failed to start the Kernel.
#
# The kernel died. Error: ... View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#reading a file into one string 
fhand = open('mbox.txt')
inp =fhand.read()
print(len(inp))
# Out:
# 6687001

# %%
#using string slicing
print(inp[:120])
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: fro

# %%
#SEARCHING THROUGH A FILE #.startswith #forloop
fhand = open('mbox.txt')
for line in fhand:
    if line.startswith('From:'):
        print(line)
# Out:
# From: stephen.marquard@uct.ac.za
#
# From: louis@media.berkeley.edu
#
# From: zqian@umich.edu
#
# From: rjlowe@iupui.edu
#
# From: zqian@umich.edu
#
# From: rjlowe@iupui.edu
#
# From: cwen@iupui.edu
#
# From: cwen@iupui.edu
#
# From: gsilver@umich.edu
#
# From: gsilver@umich.edu
#
# From: zqian@umich.edu
#
# From: gsilver@umich.edu
#
# From: wagnermr@iupui.edu
#
# From: zqian@umich.edu
#
# From: antranig@caret.cam.ac.uk
#
# From: gopal.ramasammycook@gmail.com
#
# From: david.horwitz@uct.ac.za
#
# From: david.horwitz@uct.ac.za
#
# From: david.horwitz@uct.ac.za
#
# From: david.horwitz@uct.ac.za
#
# From: stephen.marquard@uct.ac.za
#
# From: louis@media.berkeley.edu
#
# From: louis@media.berkeley.edu
#
# From: ray@media.berkeley.edu
#
# From: cwen@iupui.edu
#
# From: cwen@iupui.edu
#
# From: cwen@iupui.edu
#
# From: ray@media.berkeley.edu
#
# From: cwen@iupui.edu
#
# From: zqian@umich.edu
#
# From: cwen@iupui.edu
#
# From: zqian@umich.edu
#
# From: zqian@umich.edu
#
# ...

# %%
#striping the whitespaces from the right side of the string #rstrip
fhand = open('mbox.txt')
for line in fhand:
    line = line.rstrip()
    if line.startswith('From:'):
        print(line)

# %%
#searching loop #intresting/unintresting lines
fhand = open ('mbox.txt')
for line in fhand:
    line = line.rstrip()    #skip unintresting lines
    if not line.startswith('From:'):
        continue    #process intresting lines
    print(line)
# Out:
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: zqian@umich.edu
# From: gsilver@umich.edu
# From: wagnermr@iupui.edu
# From: zqian@umich.edu
# From: antranig@caret.cam.ac.uk
# From: gopal.ramasammycook@gmail.com
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: louis@media.berkeley.edu
# From: ray@media.berkeley.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: ray@media.berkeley.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: mmmay@indiana.edu
# From: cwen@iupui.edu
# ...

# %%
#find #forloop
fhand = open('mbox.txt')
for line in fhand:
    line = line.rstrip()
    if line.find('@uct.ac.za')== -1: continue
    print(line)

# %%
#user input option filename
fname = input('Enter the file name: ')
fhand = open(fname)
count = 0
for line in fhand:
    if line.startswith('Subject: '):
        count = count + 1
print('There were', count, 'subject lines in', fname)
# Out:
# There were 1797 subject lines in mbox.txt

# %%
#Using TRY, EXCEPT & OPEN
fname = input ('Enter the file name: ')
try:
    fhand = open(fname)
except:
    print('Invalid input! File cannot be opened:', fname)
    exit()
count = 0
for line in fhand:
    if line.startswith('Subject:'):
        count = count + 1
print('There were', count,'subject line', fname)
# Out:
# There were 1797 subject line mbox.txt

# %%
#writing files
fout = open('output.txt', 'w')
print(fout)
# Out:
# <_io.TextIOWrapper name='output.txt' mode='w' encoding='cp1252'>

# %%
line1 = 'This here is the wattle for the baby, \n' 
fout.write(line1)

line2 = 'the emblem of our land, \n'
fout.write(line2)

fout.close()

# %%
#program to read & print the entire content of a file
def read_contents(filename):
    try:
        with open(filename, 'r') as file:
            content = file.read()
            print('file contents: \n')
            print(content)
    except FileNotFoundError:
        print(f'The File',{filename},'does not exist.')
    except Exception as e:
        print(f'An Error occurred: {e}')
    
file_name = input('Enter the name of the text file: ')
read_contents(file_name)

# %%
# program to read a file line by line .strip()
def read_file_line(filename):
    try:
        with open(filename, 'r') as file:
            print(f'File contents line by line: \n ')
            for line in file:
                print(line.strip())
    except FileNotFoundError:
        print(f'The file',{filename},'does not exist.')
    except Exception as e:
        print(f'An error occurred: {e}')

file_name = input ('Enter the name of the text file: ')
read_file_line(file_name)

# %%
#program to read specific lines from a file
def spec_line(filename):
    try:
        with open(filename, 'r') as file:
            for i in range(7):
                print(file.readline().strip())
    except FileNotFoundError:
        print(f'Error: ',{filename},'not found.')

file_name = input ('Enter the name of the text file: ')
spec_line(file_name)

# %%
#program to count words from a file
import re
def count_words(filename):
    try:
        with open(filename, 'r') as file:
            content = file.read().lower()
            words = re.findall(r'\b\w+\b', content)
            return len(words)
    except FileNotFoundError:
        return f'Error: ',{file_name},'not found.'
    
word_count = count_words(file_name)
print(f'Tottal words in "filename": {word_count}')
# Out:
# Tottal words in "filename": 1135995

# %%
#program to count total number of chars in file
def count_char(filename):
    try:
        with open(filename, 'r')as file:
            content = file.read()
            return len(content)
    except FileNotFoundError as e:
        return f'Errors:', {file_name},'not found.'

char_count = count_char(file_name)
print(f'Total characters in the "{file_name}": {char_count}')

# %%
#program to write file
filename = 'new.txt'
text_to_write = 'I am nduati githu, what about you'
try:
    with open(filename, 'w') as file:
        file.write(text_to_write)
    print(f'successfully wrote',{text_to_write},'to',{file_name},'.')
    
except Exception as e:
    print(f'An error occured: {e}')
# Out:
# successfully wrote {'I am nduati githu, what about you'} to {'mbox.txt'} .

# %%
# program to read & write binary file   
def copy_binary(source_filename, destination_filename):
    try:
        with open(source_filename, 'rb')as source_file:
            binary_content = source_file.read()
        with open(destination_filename, 'wb')as destination_file:
            destination_file.write(binary_content)
        print(f"Successfully copied bin file: '{source_filename}'to'{destination_filename}'.")
        
    except Exception as e:
        print(f'Error: source binary file',{source_filename},'not found.')

source_file = input('Enter the name of the binary file: ')        
source_binary_file =(source_file)
destination_binary_file ='output.bin'
copy_binary(source_binary_file, destination_binary_file)
# Out:
# Successfully copied bin file: 'input.bin'to'output.bin'.

# %%
#program to check file existance
import os
def check_file_exists(filename):
    return os.path.exists(filename)

file_name = input('Enter the name of the file to be checked:')
filename = (file_name)
exists = check_file_exists(filename)
print(f'Does',(filename),'exist?',(exists),)
# Out:
# Does new.txt exist? True

# %%
#program to get file size
import os
def get_size(filename):
    try:
        size_in_bytes = os.path.getsize(filename)
        return size_in_bytes
    except FileNotFoundError:
        return f'Error:',{file_name},'not found.'

file_name = input('Enter the file name: ')
filename = (file_name)
size = get_size(filename)
print(f'The size of the file',(file_name),'is',(size),'bytes')
# Out:
# The size of the file mbox.txt is 6819045 bytes

# %%
#program to rename file
import os
def rename_file(old_filename, new_filename):
    if not os.path.exists(old_filename):
        return f'Error:File',(old_filename),'not found.'
    try:
        os.rename(old_filename, new_filename)
        return f'Successfully renamed',{old_filename},'to',{new_filename},'.'
    except Exception as e:
        return f'An error occured: {e}'
    
old_name = input('Enter the name of the file:')
new_name = input('Enter the name of the new file:')
